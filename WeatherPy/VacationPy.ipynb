# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame

city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID          City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0         tagta  41.6504   59.9164     33.63        22          18
# 1        1     kyshtovka  56.5550   76.6271     18.52        62         100
# 2        2  puerto aysen -45.4000  -72.7000      6.98       100         100
# 3        3        illizi  26.4833    8.4667     30.45         8           0
# 4        4   yellowknife  62.4560 -114.3525     12.31        58          99
#
#    Wind Speed Country        Date
# 0        5.39      TM  1717992415
# 1        4.47      RU  1717992415
# 2        0.22      CL  1717992415
# 3        4.64      DZ  1717992415
# 4        2.31      CA  1717992416

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
# YOUR CODE HERE
cityMap = city_data_df.hvplot.points("Lng", 
                                      "Lat", 
                                      geo = True,
                                      color = "City",
                                      alpha = 0.6,
                                      size = "Humidity",
                                      tiles = "OSM"
                                     )

# Display the map
# YOUR CODE HERE
hvplot.save(cityMap, 'output_data/city_map.html')
cityMap
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
# YOUR CODE HERE
weatherDF = city_data_df.loc[(city_data_df["Max Temp"] < 27)
                                       & (city_data_df["Max Temp"] > 21) 
                                       & (city_data_df["Cloudiness"] < 3)
                                       & (city_data_df["Wind Speed"] < 4.5)
                                      ]
# Drop any rows with null values
# YOUR CODE HERE
weatherDF.dropna()


# Display sample data
# YOUR CODE HERE
weatherDF
# Out:
#      City_ID                  City      Lat       Lng  Max Temp  Humidity  \
# 16        16         alice springs -23.7000  133.8833     22.75        25
# 32        32              columbia  34.0007  -81.0348     25.80        75
# 67        67             al badari  26.9926   31.4155     26.59        34
# 74        74             fortaleza  -3.7227  -38.5247     26.23        83
# 84        84           tamanrasset  22.7850    5.5228     25.95        13
# 89        89                newman  37.3138 -121.0208     24.13        52
# 101      101               nafplio  37.5683   22.8053     25.91        52
# 132      132              benghazi  32.1167   20.0667     23.83        50
# 266      266                 barra -11.0894  -43.1417     23.10        67
# 289      289              tallulah  32.4085  -91.1868     24.00        88
# 291      291               corinto  37.9407   22.9573     25.13        55
# 294      294               formosa -26.1775  -58.1781     21.09        82
# 321      321           antsiranana -12.2787   49.2917     21.60        64
# 341      341          saint-pierre -21.3393   55.4781     21.21        68
# 381      381             saruhanli  38.7346   27.5681     22.31        54
# 390      390                 kabul  34.5000   69.4167     21.66        23
# 392      392             al qusayr  34.5091   36.5798     23.12        55
# 400      400                waddan  29.1614   16.1390     26.94        15
# 404      404              imbituba -28.2400  -48.6703     21.03        79
# 411      411         flinders view -27.6505  152.7745     23.88        31
# 426      426            andergrove -21.0833  149.1833     26.94        53
# 433      433         santa rosalia  27.3167 -112.2833     26.88        35
# 468      468                ongjin  37.9347  125.3619     24.00        69
# 469      469        khamis mushait  18.3064   42.7292     24.58        49
# 506      506  gardnerville ranchos  38.8882 -119.7413     23.94        34
# 548      548          stephenville  32.2207  -98.2023     26.25        79
# 549      549                 sitia  35.2000   26.0986     26.10        49
# 554      554           ra's bayrut  33.9000   35.4833     26.17        69
# 566      566               bardsir  29.9227   56.5743     23.21        13
# 579      579           al burayqah  30.4062   19.5739     22.80        61
#
#      Cloudiness  Wind Speed Country        Date
# 16            0        2.57      AU  1717992418
# 32            0        1.54      US  1717992170
# 67            0        2.99      EG  1717992426
# 74            0        3.60      BR  1717992427
# 84            0        3.09      DZ  1717992429
# 89            0        3.15      US  1717992430
# 101           0        1.64      GR  1717992432
# 132           0        3.82      LY  1717992438
# 266           2        1.65      BR  1717992467
# 289           0        0.00      US  1717992471
# 291           2        1.54      GR  1717992472
# 294           0        2.80      AR  1717992472
# 321           1        3.18      MG  1717992477
# 341           0        2.57      RE  1717992481
# 381           0        1.03      TR  1717992488
# 390           0        1.94      AF  1717992315
# 392           0        1.18      SY  1717992492
# 400           0        3.46      LY  1717992493
# 404           2        1.78      BR  1717992494
# 411           0        3.09      AU  1717992495
# 426           0        4.45      AU  1717992498
# 433           0        4.13      MX  1717992499
# 468           1        3.62      KP  1717992505
# 469           0        2.06      SA  1717992506
# 506           0        0.00      US  1717992512
# 548           0        0.00      US  1717992519
# 549           0        3.04      GR  1717992520
# 554           0        2.57      LB  1717992520
# 566           0        1.92      IR  1717992522
# 579           0        1.44      LY  1717992525

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
# YOUR CODE HERE
hotel_df = weatherDF[["City", "Country", "Lat", "Lng", "Humidity"]].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
# YOUR CODE HERE
hotel_df["Hotel Name"] = ""

# Display sample data
# YOUR CODE HERE
hotel_df
# Out:
#                      City Country      Lat       Lng  Humidity Hotel Name
# 16          alice springs      AU -23.7000  133.8833        25
# 32               columbia      US  34.0007  -81.0348        75
# 67              al badari      EG  26.9926   31.4155        34
# 74              fortaleza      BR  -3.7227  -38.5247        83
# 84            tamanrasset      DZ  22.7850    5.5228        13
# 89                 newman      US  37.3138 -121.0208        52
# 101               nafplio      GR  37.5683   22.8053        52
# 132              benghazi      LY  32.1167   20.0667        50
# 266                 barra      BR -11.0894  -43.1417        67
# 289              tallulah      US  32.4085  -91.1868        88
# 291               corinto      GR  37.9407   22.9573        55
# 294               formosa      AR -26.1775  -58.1781        82
# 321           antsiranana      MG -12.2787   49.2917        64
# 341          saint-pierre      RE -21.3393   55.4781        68
# 381             saruhanli      TR  38.7346   27.5681        54
# 390                 kabul      AF  34.5000   69.4167        23
# 392             al qusayr      SY  34.5091   36.5798        55
# 400                waddan      LY  29.1614   16.1390        15
# 404              imbituba      BR -28.2400  -48.6703        79
# 411         flinders view      AU -27.6505  152.7745        31
# 426            andergrove      AU -21.0833  149.1833        53
# 433         santa rosalia      MX  27.3167 -112.2833        35
# 468                ongjin      KP  37.9347  125.3619        69
# 469        khamis mushait      SA  18.3064   42.7292        49
# 506  gardnerville ranchos      US  38.8882 -119.7413        34
# 548          stephenville      US  32.2207  -98.2023        79
# 549                 sitia      GR  35.2000   26.0986        49
# 554           ra's bayrut      LB  33.9000   35.4833        69
# 566               bardsir      IR  29.9227   56.5743        13
# 579           al burayqah      LY  30.4062   19.5739        61

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {"categories": "accommodation.hotel",
          "apiKey": geoapify_key
         }

print(params)


# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    # YOUR CODE HERE
    longitude = row["Lng"]
    latitude = row["Lat"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] =  f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params = params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()

    name_address
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# {'categories': 'accommodation.hotel', 'apiKey': '9837b5541d944ebd975566d7004ed815'}
# Starting hotel search
# alice springs - nearest hotel: Aurora Alice Springs
# columbia - nearest hotel: Cambria Hotel
# al badari - nearest hotel: No hotel found
# fortaleza - nearest hotel: Hotel Catedral
# tamanrasset - nearest hotel: فندق الأمان
# newman - nearest hotel: No hotel found
# nafplio - nearest hotel: Ναυπλία
# benghazi - nearest hotel: ترجاب
# barra - nearest hotel: No hotel found
# tallulah - nearest hotel: No hotel found
# corinto - nearest hotel: Apollon
# formosa - nearest hotel: Hotel Hostal del Rey
# antsiranana - nearest hotel: Central
# saint-pierre - nearest hotel: Tropic Hotel
# saruhanli - nearest hotel: No hotel found
# kabul - nearest hotel: No hotel found
# al qusayr - nearest hotel: No hotel found
# waddan - nearest hotel: No hotel found
# imbituba - nearest hotel: Silvestre Praia Hotel
# flinders view - nearest hotel: Quest Ipswich
# andergrove - nearest hotel: No hotel found
# santa rosalia - nearest hotel: Sol y Mar
# ongjin - nearest hotel: No hotel found
# khamis mushait - nearest hotel: No hotel found
# gardnerville ranchos - nearest hotel: Holiday Inn
# stephenville - nearest hotel: No hotel found
# sitia - nearest hotel: Itanos Hotel
# ra's bayrut - nearest hotel: ثري أو ناين
# bardsir - nearest hotel: No hotel found
# al burayqah - nearest hotel: فندق ماس ليبيا
#                      City Country      Lat       Lng  Humidity  \
# 16          alice springs      AU -23.7000  133.8833        25
# 32               columbia      US  34.0007  -81.0348        75
# 67              al badari      EG  26.9926   31.4155        34
# 74              fortaleza      BR  -3.7227  -38.5247        83
# 84            tamanrasset      DZ  22.7850    5.5228        13
# 89                 newman      US  37.3138 -121.0208        52
# 101               nafplio      GR  37.5683   22.8053        52
# 132              benghazi      LY  32.1167   20.0667        50
# 266                 barra      BR -11.0894  -43.1417        67
# 289              tallulah      US  32.4085  -91.1868        88
# 291               corinto      GR  37.9407   22.9573        55
# 294               formosa      AR -26.1775  -58.1781        82
# 321           antsiranana      MG -12.2787   49.2917        64
# 341          saint-pierre      RE -21.3393   55.4781        68
# 381             saruhanli      TR  38.7346   27.5681        54
# 390                 kabul      AF  34.5000   69.4167        23
# 392             al qusayr      SY  34.5091   36.5798        55
# 400                waddan      LY  29.1614   16.1390        15
# 404              imbituba      BR -28.2400  -48.6703        79
# 411         flinders view      AU -27.6505  152.7745        31
# 426            andergrove      AU -21.0833  149.1833        53
# 433         santa rosalia      MX  27.3167 -112.2833        35
# 468                ongjin      KP  37.9347  125.3619        69
# 469        khamis mushait      SA  18.3064   42.7292        49
# 506  gardnerville ranchos      US  38.8882 -119.7413        34
# 548          stephenville      US  32.2207  -98.2023        79
# 549                 sitia      GR  35.2000   26.0986        49
# 554           ra's bayrut      LB  33.9000   35.4833        69
# 566               bardsir      IR  29.9227   56.5743        13
# 579           al burayqah      LY  30.4062   19.5739        61
#
#                 Hotel Name
# 16    Aurora Alice Springs
# 32           Cambria Hotel
# 67          No hotel found
# 74          Hotel Catedral
# 84             فندق الأمان
# 89          No hotel found
# 101                Ναυπλία
# 132                  ترجاب
# 266         No hotel found
# 289         No hotel found
# 291                Apollon
# 294   Hotel Hostal del Rey
# 321                Central
# 341           Tropic Hotel
# 381         No hotel found
# 390         No hotel found
# 392         No hotel found
# 400         No hotel found
# 404  Silvestre Praia Hotel
# 411          Quest Ipswich
# 426         No hotel found
# 433              Sol y Mar
# 468         No hotel found
# 469         No hotel found
# 506            Holiday Inn
# 548         No hotel found
# 549           Itanos Hotel
# 554            ثري أو ناين
# 566         No hotel found
# 579         فندق ماس ليبيا

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
# YOUR CODE HERE
hotel_map = hotel_df.hvplot.points("Lng", 
                                   "Lat", 
                                   geo = True,
                                   color = "City",
                                   alpha = 0.8,
                                   size = "Humidity",
                                   tiles = "OSM",
                                   hover_cols = ["Hotel Name", "Country"]
                                  )

# Display the map
# YOUR CODE HERE
hvplot.save(hotel_map, 'output_data/hotel_map.html')
hotel_map
# Out:
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: figure(id='p1422', ...)
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
